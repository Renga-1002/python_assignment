# %% [markdown]
# # RENGA PRASAD A

# %% [markdown]
# # <h3>235229128</h3>

# %% [markdown]
# # <h3> ASSIGNMENT-5 </h3>

# %% [markdown]
# # <h1>Question1. Write a program for Fruit Inventory Management.</h1>
# 1. Create a dictionary fruits with fruit name as key and quantity available as values.
# There are 20 apples, 50 bananas, 100 oranges. Then, print outputs for the following
# queries.
# 2. Show the entire dictionary fruits (Print output as apples -> 20, bananas -> 50, etc)
# 3. How many bananas are there?
# 4. How many items in the dictionary?
# 5. Does graphs available in the dictionary?
# 6. Does pears exists in the dictionary?. If so, return its quantity, otherwise, add 10
# pears to dictionary.
# 7. Show all fruit names in ascending order (Iterate using for loop)
# 8. Show all fruits in descending order of quantities
# 9. Remove pears from the dictionary.
# 10. Develop a function show() that displays fruit name and quantity (Use .format() for
# pretty printing)
# 11. Develop a function add_fruit(name, quantity) that receives fruit name and quantity
# as input and increases the quantity of the fruit. Then, display the current inventory
# by calling show().
# 12. Now, add 40 apples to inventory by calling add_fruit(name, quantity)
# 13. Now, add 100 bananas to inventory, by calling add_fruit(name, quantity)
# 14. Now, show the current inventory, by calling show()
# 15. Write the inventory fruits onto a file. (Use Pickle for file writing and reading)
# 16. Now, open Pickle file and display the inventory.

# %%
# import pickle

# Step 1: Create the fruits dictionary
fruits = {'apples': 20,'bananas': 50,'oranges': 100}
# Step 2: Show the entire dictionary fruits
print("Step 2:")
print(fruits)

# Step 3: How many bananas are there?
print("\nStep 3:")
print(f"There are {fruits['bananas']} bananas.")

# Step 4: How many items in the dictionary?
print("\nStep 4:")
print(f"There are {len(fruits)} items in the dictionary.")

# Step 5: Does 'graphs' available in the dictionary?
print("\nStep 5:")
print("Yes" if 'graphs' in fruits else "No")

# Step 6: Does 'pears' exist in the dictionary?
print("\nStep 6:")
if 'pears' in fruits:
    print(f"Pears quantity: {fruits['pears']}")
else:
    fruits['pears'] = 10
    print("Pears added to the dictionary.")

# Step 7: Show all fruit names in ascending order
print("\nStep 7:")
for fruit in sorted(fruits.keys()):
    print(fruit)

# Step 8: Show all fruits in descending order of quantities
print("\nStep 8:")
for fruit, quantity in sorted(fruits.items(), key=lambda x: x[1], reverse=True):
    print(f"{fruit} -> {quantity}")

# Step 9: Remove pears from the dictionary
print("\nStep 9:")
fruits.pop('pears', None)
print("Pears removed from the dictionary.")

# Step 10: Develop a function show() for pretty printing
print("\nStep 10:")
def show():
    for fruit, quantity in fruits.items():
        print("{:<10} -> {:>4}".format(fruit, quantity))

show()

# Step 11: Develop a function add_fruit(name, quantity)
print("\nStep 11:")
def add_fruit(name, quantity):
    if name in fruits:
        fruits[name] += quantity
    else:
        fruits[name] = quantity

add_fruit('apples', 40)  # Step 12
add_fruit('bananas', 100)  # Step 13

# Step 14: Show the current inventory
print("\nStep 14:")
show()

# Step 15: Write the inventory fruits onto a file using Pickle
print("\nStep 15:")
with open('fruits_inventory.pkl', 'wb') as file:
    pickle.dump(fruits, file)
    print("Inventory saved to 'fruits_inventory.pkl'.")

# Step 16: Read and display the inventory from the Pickle file
print("\nStep 16:")
with open('fruits_inventory.pkl', 'rb') as file:
    inventory_from_file = pickle.load(file)
    print("Inventory loaded from 'fruits_inventory.pkl':")
    show()
# Out:
# Step 2:
# {'apples': 20, 'bananas': 50, 'oranges': 100}
#
# Step 3:
# There are 50 bananas.
#
# Step 4:
# There are 3 items in the dictionary.
#
# Step 5:
# No
#
# Step 6:
# Pears added to the dictionary.
#
# Step 7:
# apples
# bananas
# oranges
# pears
#
# Step 8:
# oranges -> 100
# bananas -> 50
# apples -> 20
# pears -> 10
#
# Step 9:
# Pears removed from the dictionary.
#
# Step 10:
# apples     ->   20
# bananas    ->   50
# oranges    ->  100
#
# Step 11:
#
# Step 14:
# apples     ->   60
# bananas    ->  150
# oranges    ->  100
#
# Step 15:
# Inventory saved to 'fruits_inventory.pkl'.
#
# Step 16:
# Inventory loaded from 'fruits_inventory.pkl':
# apples     ->   60
# bananas    ->  150
# oranges    ->  100

# %% [markdown]
# # <h3>Question2. Write a program for Telephone Directory Management</h3>
# 1. Create an empty dictionary called customers, where name is a key and contacts is a
# list of contacts such as phoneno and email ID for each customer.
# 2. Ask user to enter name and his contacts for N customers. Add them to dictionary
# customers. Stop reading when user types “done”.
# 3. Show the contacts for customer “rex”. If not exists, print message “Contacts not
# exists..”
# 4. Add a new customer with name “rex”, phone number 9942002764 and email id
# rajkumar@bhc.edu
# 5. Show all customers both name and contacts. (Use items() method, unpack it and
# print inside for loop)
# 6. Show all customer contacts (Iterate using for loop)
# 7. Show all customer names in alphabetical order
# 8. How many customers are there in your dictionary?
# 9. Remove customer “rex” from dictionary customers

# %%
customers = {}

# Step 2: Ask the user to enter name and contacts for N customers
print("Step 2:")
while True:
    name = input("Enter customer name (type 'done' to stop): ")
    if name.lower() == 'done':
        break

    phone_no = input("Enter customer phone number: ")
    email_id = input("Enter customer email ID: ")

    customers[name] = {'phoneno': phone_no, 'email': email_id}

# Step 3: Show the contacts for customer "rex"
print("\nStep 3:")
rex_contacts = customers.get('rex')
if rex_contacts:
    print("Contacts for customer 'rex':")
    print("Phone No:", rex_contacts['phoneno'])
    print("Email ID:", rex_contacts['email'])
else:
    print("Contacts for customer 'rex' do not exist.")

# Step 4: Add a new customer with name "rex"
print("\nStep 4:")
customers['rex'] = {'phoneno': '9942002764', 'email': 'rajkumar@bhc.edu'}
print("Customer 'rex' added successfully.")

# Step 5: Show all customers both name and contacts
print("\nStep 5:")
for name, contacts in customers.items():
    print(f"Customer: {name}")
    print("Phone No:", contacts['phoneno'])
    print("Email ID:", contacts['email'])
    print()

# Step 6: Show all customer contacts
print("\nStep 6:")
for contacts in customers.values():
    print("Phone No:", contacts['phoneno'])
    print("Email ID:", contacts['email'])
    print()

# Step 7: Show all customer names in alphabetical order
print("\nStep 7:")
for name in sorted(customers.keys()):
    print(name)

# Step 8: How many customers are there in your dictionary?
print("\nStep 8:")
num_customers = len(customers)
print(f"There are {num_customers} customers in the dictionary.")

# Step 9: Remove customer "rex" from dictionary customers
print("\nStep 9:")
if 'rex' in customers:
    del customers['rex']
    print("Customer 'rex' removed from the dictionary.")
else:
    print("Customer 'rex' does not exist in the dictionary.")
# Out:
# Step 2:
# Enter customer name (type 'done' to stop): renga
# Enter customer phone number: 909267306
# Enter customer email ID: renga@bhc.edu.in
# Enter customer name (type 'done' to stop): pavi
# Enter customer phone number: 9092667306
# Enter customer email ID: pavi@bhc.edu.in
# Enter customer name (type 'done' to stop): done
#
# Step 3:
# Contacts for customer 'rex' do not exist.
#
# Step 4:
# Customer 'rex' added successfully.
#
# Step 5:
# Customer: renga
# Phone No: 909267306
# Email ID: renga@bhc.edu.in
#
# Customer: pavi
# Phone No: 9092667306
# Email ID: pavi@bhc.edu.in
#
# Customer: rex
# Phone No: 9942002764
# Email ID: rajkumar@bhc.edu
#
#
# Step 6:
# Phone No: 909267306
# Email ID: renga@bhc.edu.in
#
# Phone No: 9092667306
# Email ID: pavi@bhc.edu.in
#
# Phone No: 9942002764
# Email ID: rajkumar@bhc.edu
#
#
# Step 7:
# pavi
# renga
# rex
#
# Step 8:
# There are 3 customers in the dictionary.
#
# Step 9:
# Customer 'rex' removed from the dictionary.

# %% [markdown]
# # <h3>Question3. Write a program for Character and word counter.</h3>
#  Develop an application that reads a file and prints words in descending order of their
# frequency.
#  Also print the letters such as ‘a’, , ‘b’, etc, in decreasing order of frequency. Your
# program should convert all the input to lower case and only count the letters a-z.
# Your program should not count spaces, digits, punctuation, or anything other than
# the letters a-z.

# %%
import re

with open('sample_file.txt', 'r') as file:
    text = file.read().lower()

words = re.findall(r'\b[a-z]+\b', text)
char_counts = {}
for char in text:
    if char.isalpha():
        char_counts[char] = char_counts.get(char, 0) + 1

word_counts = {}
for word in words:
    word_counts[word] = word_counts.get(word, 0) + 1

sorted_characters = sorted(char_counts.items(), key=lambda item: item[1], reverse=True)
sorted_words = sorted(word_counts.items(), key=lambda item: item[1], reverse=True)
print("Characters frequency:")
for char, freq in sorted_characters:
    print(f"{char}: {freq}")

print("\nWords frequency:")
for word, freq in sorted_words:
    print(f"{word}: {freq}")
# Out:
# Characters frequency:
# e: 94
# r: 71
# i: 70
# t: 69
# a: 66
# s: 65
# n: 61
# o: 54
# h: 32
# c: 31
# p: 30
# l: 30
# d: 25
# u: 21
# f: 19
# w: 14
# b: 13
# m: 12
# g: 12
# y: 11
# k: 10
# v: 4
# j: 1
# x: 1
#
# Words frequency:
# in: 9
# the: 8
# and: 7
# is: 6
# rock: 3
# to: 3
# pipits: 3
# an: 3
# european: 2
# pipit: 2
# a: 2
# small: 2
# of: 2
# europe: 2
# on: 2
# it: 2
# which: 2
# only: 2
# resident: 2
# from: 2
# or: 2
# anthus: 1
# petrosus: 1
# species: 1
# songbird: 1
# that: 1
# breeds: 1
# western: 1
# rocky: 1
# coasts: 1
# has: 1
# streaked: 1
# greyish: 1
# brown: 1
# upperparts: 1
# buff: 1
# underparts: 1
# similar: 1
# appearance: 1
# other: 1
# there: 1
# are: 1
# three: 1
# subspecies: 1
# fennoscandian: 1
# form: 1
# migratory: 1
# wintering: 1
# shoreline: 1
# habitats: 1
# further: 1
# south: 1
# northwest: 1
# africa: 1
# territorial: 1
# at: 1
# least: 1
# breeding: 1
# season: 1
# remains: 1
# so: 1
# year: 1
# round: 1
# where: 1
# males: 1
# will: 1
# sometimes: 1
# enter: 1
# adjacent: 1
# territory: 1
# assist: 1
# repelling: 1
# intruder: 1
# behaviour: 1
# otherwise: 1
# known: 1
# african: 1
# fiddler: 1
# crab: 1
# construct: 1
# cup: 1
# nest: 1
# under: 1
# coastal: 1
# vegetation: 1
# cliff: 1
# crevices: 1
# lay: 1
# four: 1
# six: 1
# speckled: 1
# pale: 1
# grey: 1
# eggs: 1
# hatch: 1
# about: 1
# two: 1
# weeks: 1
# feed: 1
# mainly: 1
# invertebrates: 1
# picked: 1
# off: 1
# rocks: 1
# shallow: 1
# water: 1
# occasionally: 1
# catch: 1
# insects: 1
# flight: 1
# bird: 1
# s: 1
# population: 1
# large: 1
# stable: 1

# %% [markdown]
# # <h3>Question4. Using Email Collections file, mbox-short.txt, write a python program for the
# following queries.</h3>
# 1. Search for lines that contain 'From' and print them
# 2. Search for lines that start with 'From' and print them
# 3. Search for lines that start with 'F', followed by 2 characters, followed by 'm:'
# 4. Search for lines that start with From and have an at sign and print them
# 5. Search for lines that have an at sign between characters and print them (Use
# findall())
# 6. Search for lines that have an at sign between characters. The characters must be a
# letter or number and print them
# 7. Search for lines that start with 'X' followed by any non white space characters and ':',
# followed by a space and any number. The number can include a decimal.
# 8. Search for lines that start with 'X' followed by any non whitespace characters and ':'
# followed by a space and any number. The number can include a decimal. Then print
# the number if it is greater than zero.
# 9. Search for lines that start with 'Details: rev=', followed by numbers and '.'. Then print
# the number if it is greater than zero
# 10. Search for lines that start with From and a character followed by a two digit number
# between 00 and 99 followed by ':'. Then print the number if it is greater than zero

# %%
import re
with open("mbox-short copy.txt", 'r') as file:
    lines = file.readlines()

# %%
# 1
"""Search for lines that contain 'From' and print them"""
print("Lines that contain 'From':")
for line in lines:
    if 'From' in line:
        print(line.rstrip())
# Out:
# Lines that contain 'From':
# From: sender@example.com
# From: john@example.com
# From A12: This line has a number less than 00
# From B56: This line has a number greater than 00
# From C00: This line has a number equal to 00
# From D101: This line has a number greater than 99
# From X123: 12.5
# From Y45: 0.987
# From Z78: -3.14
# From Q01: 3.14
# From R99: 0
# From A00: 2.718
# From: test@example.com
# From T09: 1.414
# From U10: 0.5
# From V17: 2.718
# From: user@example.com
# From W89: 0.1
# From X90: 0
# From Y34: 3.14
# From Z12: -1.414

# %%
# 2
"""Search for lines that start with 'From' and print them"""
print("Lines that start with 'From':")
for line in lines:
    if line.startswith('From'):
        print(line.rstrip())
# Out:
# Lines that start with 'From':
# From: sender@example.com
# From: john@example.com
# From A12: This line has a number less than 00
# From B56: This line has a number greater than 00
# From C00: This line has a number equal to 00
# From D101: This line has a number greater than 99
# From X123: 12.5
# From Y45: 0.987
# From Z78: -3.14
# From Q01: 3.14
# From R99: 0
# From A00: 2.718
# From: test@example.com
# From T09: 1.414
# From U10: 0.5
# From V17: 2.718
# From: user@example.com
# From W89: 0.1
# From X90: 0
# From Y34: 3.14
# From Z12: -1.414

# %%
# 3
"""Search for lines that start with 'F', followed by 2 characters, followed by 'm:'"""
print("Lines that match 'F__m:' pattern:")
for line in lines:
    if re.search(r'F..m:', line):
        print(line.rstrip())
# Out:
# Lines that match 'F__m:' pattern:
# From: sender@example.com
# From: john@example.com
# From: test@example.com
# From: user@example.com

# %%
# 4
"""Search for lines that start with From and have an at sign and print them"""
print("Lines starting with 'From' and containing '@':")
for line in lines:
    if re.search(r'^From.*@', line):
        print(line.rstrip())
# Out:
# Lines starting with 'From' and containing '@':
# From: sender@example.com
# From: john@example.com
# From: test@example.com
# From: user@example.com

# %%
# 5
"""Search for lines that have an at sign between characters and print them (Use
findall())"""
print("Lines with at sign between characters:")
for line in lines:
    matches = re.findall(r'\S+@\S+', line)
    if matches:
        print(matches)
# Out:
# Lines with at sign between characters:
# ['sender@example.com']
# ['john@example.com']
# ['example@gmail.com']
# ['another@example.com']
# ['test@example.com']
# ['123@example.org']
# ['test@example.com']
# ['user@example.com']
# ['test@example.com']
# ['user@example.com']
# ['contact@example.com']
# ['info@example.com']
# ['xyz@example.com']
# ['abc@example.com']
# ['sample@example.com']
# ['test@example.com']
# ['sample@example.com']
# ['user@example.com']
# ['contact@example.com']
# ['info@example.com']
# ['xyz@example.com']
# ['abc@example.com']
# ['john@example.com']
# ['sender@example.com']
# ['another@example.com']
# ['example@gmail.com']
# ['test@example.org']
# ['123@example.org']
# ['example@example.org']
# ['sample@example.org']
# ['user@example.org']
# ['contact@example.org']
# ['info@example.org']
# ['xyz@example.org']
# ['abc@example.org']
# ['john@example.org']
# ['sender@example.org']
# ['another@example.org']
# ['test@domain.com']
# ['sample@domain.com']
# ['user@domain.com']
# ['contact@domain.com']
# ['info@domain.com']
# ['xyz@domain.com']
# ['abc@domain.com']
# ['john@domain.com']
# ['sender@domain.com']
# ['another@domain.com']
# ['test@example.net']
# ['sample@example.net']
# ['user@example.net']
# ['contact@example.net']
# ['info@example.net']
# ['xyz@example.net']
# ['abc@example.net']
# ['john@example.net']
# ['sender@example.net']
# ['another@example.net']
# ['test@domain.net']
# ['sample@domain.net']
# ['user@domain.net']
# ['contact@domain.net']
# ['info@domain.net']
# ['xyz@domain.net']
# ['abc@domain.net']
# ['john@domain.net']
# ['sender@domain.net']
# ['another@domain.net']
# ['test@example.co.uk']
# ['sample@example.co.uk']
# ['user@example.co.uk']
# ['contact@example.co.uk']
# ['info@example.co.uk']
# ['xyz@example.co.uk']
# ['abc@example.co.uk']
# ['john@example.co.uk']
# ['sender@example.co.uk']
# ['another@example.co.uk']
# ['test@domain.co.uk']
# ['sample@domain.co.uk']
# ['user@domain.co.uk']
# ['contact@domain.co.uk']
# ['info@domain.co.uk']
# ['xyz@domain.co.uk']
# ['abc@domain.co.uk']
# ['john@domain.co.uk']
# ['sender@domain.co.uk']
# ['another@domain.co.uk']
# ['test@example.ca']
# ['sample@example.ca']
# ['user@example.ca']
# ['contact@example.ca']
# ['info@example.ca']
# ['xyz@example.ca']
# ['abc@example.ca']
# ['john@example.ca']
# ['sender@example.ca']
# ['another@example.ca']
# ['test@domain.ca']
# ['sample@domain.ca']
# ['user@domain.ca']
# ['contact@domain.ca']
# ['info@domain.ca']
# ['xyz@domain.ca']
# ['abc@domain.ca']
# ['john@domain.ca']
# ['sender@domain.ca']
# ['another@domain.ca']
# ['test@example.us']
# ['sample@example.us']
# ['user@example.us']
# ['contact@example.us']
# ['info@example.us']
# ['xyz@example.us']
# ['abc@example.us']
# ['john@example.us']
# ['sender@example.us']
# ['another@example.us']
# ['test@domain.us']
# ['sample@domain.us']
# ['user@domain.us']
# ['contact@domain.us']
# ['info@domain.us']
# ['xyz@domain.us']
# ['abc@domain.us']
# ['john@domain.us']
# ['sender@domain.us']
# ['another@domain.us']
# ['test@example.io']
# ['sample@example.io']
# ['user@example.io']
# ['contact@example.io']
# ['info@example.io']
# ['xyz@example.io']
# ['abc@example.io']
# ['john@example.io']
# ['sender@example.io']
# ['another@example.io']
# ['test@domain.io']
# ['sample@domain.io']
# ['user@domain.io']
# ['contact@domain.io']
# ['info@domain.io']
# ['xyz@domain.io']
# ['abc@domain.io']
# ['john@domain.io']
# ['sender@domain.io']
# ['another@domain.io']
# ['test@example.org.uk']
# ['sample@example.org.uk']
# ['user@example.org.uk']
# ['contact@example.org.uk']
# ['info@example.org.uk']
# ['xyz@example.org.uk']
# ['abc@example.org.uk']
# ['john@example.org.uk']
# ['sender@example.org.uk']
# ['another@example.org.uk']
# ['test@domain.org.uk']
# ['sample@domain.org.uk']
# ['user@domain.org.uk']
# ['contact@domain.org.uk']
# ['info@domain.org.uk']
# ['xyz@domain.org.uk']
# ['abc@domain.org.uk']
# ['john@domain.org.uk']
# ['sender@domain.org.uk']
# ['another@domain.org.uk']
# ['test@example.com.au']
# ['sample@example.com.au']
# ['user@example.com.au']
# ['contact@example.com.au']
# ['info@example.com.au']
# ['xyz@example.com.au']
# ['abc@example.com.au']
# ['john@example.com.au']
# ['sender@example.com.au']
# ['another@example.com.au']
# ['test@domain.com.au']
# ['sample@domain.com.au']
# ['user@domain.com.au']
# ['contact@domain.com.au']
# ['info@domain.com.au']
# ['xyz@domain.com.au']
# ['abc@domain.com.au']
# ['john@domain.com.au']

# %%
# 6
"""Search for lines that have an at sign between characters. The characters must be a
letter or number and print them"""
print("Lines with at sign between letters or numbers:")
for line in lines:
    matches = re.findall(r'[a-zA-Z0-9]+@[a-zA-Z0-9]+', line)
    if matches:
        print(matches)
# Out:
# Lines with at sign between letters or numbers:
# ['sender@example']
# ['john@example']
# ['example@gmail']
# ['another@example']
# ['test@example']
# ['123@example']
# ['test@example']
# ['user@example']
# ['test@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['sample@example']
# ['test@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['example@gmail']
# ['test@example']
# ['123@example']
# ['example@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['test@domain']
# ['sample@domain']
# ['user@domain']
# ['contact@domain']
# ['info@domain']
# ['xyz@domain']
# ['abc@domain']
# ['john@domain']
# ['sender@domain']
# ['another@domain']
# ['test@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['test@domain']
# ['sample@domain']
# ['user@domain']
# ['contact@domain']
# ['info@domain']
# ['xyz@domain']
# ['abc@domain']
# ['john@domain']
# ['sender@domain']
# ['another@domain']
# ['test@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['test@domain']
# ['sample@domain']
# ['user@domain']
# ['contact@domain']
# ['info@domain']
# ['xyz@domain']
# ['abc@domain']
# ['john@domain']
# ['sender@domain']
# ['another@domain']
# ['test@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['test@domain']
# ['sample@domain']
# ['user@domain']
# ['contact@domain']
# ['info@domain']
# ['xyz@domain']
# ['abc@domain']
# ['john@domain']
# ['sender@domain']
# ['another@domain']
# ['test@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['test@domain']
# ['sample@domain']
# ['user@domain']
# ['contact@domain']
# ['info@domain']
# ['xyz@domain']
# ['abc@domain']
# ['john@domain']
# ['sender@domain']
# ['another@domain']
# ['test@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['test@domain']
# ['sample@domain']
# ['user@domain']
# ['contact@domain']
# ['info@domain']
# ['xyz@domain']
# ['abc@domain']
# ['john@domain']
# ['sender@domain']
# ['another@domain']
# ['test@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['test@domain']
# ['sample@domain']
# ['user@domain']
# ['contact@domain']
# ['info@domain']
# ['xyz@domain']
# ['abc@domain']
# ['john@domain']
# ['sender@domain']
# ['another@domain']
# ['test@example']
# ['sample@example']
# ['user@example']
# ['contact@example']
# ['info@example']
# ['xyz@example']
# ['abc@example']
# ['john@example']
# ['sender@example']
# ['another@example']
# ['test@domain']
# ['sample@domain']
# ['user@domain']
# ['contact@domain']
# ['info@domain']
# ['xyz@domain']
# ['abc@domain']
# ['john@domain']

# %%
# 7
"""Search for lines that start with 'X' followed by any non white space characters and ':',
followed by a space and any number. The number can include a decimal."""
print("Numbers after 'X__:' pattern:")
for line in lines:
    matches = re.findall(r'X\S+: (\d+(\.\d+)?)', line)
    for match in matches:
        if float(match[0]) > 0:
            print(match[0])
# Out:
# Numbers after 'X__:' pattern:
# 12.5
# 0.5

# %%
# 8
"""Search for lines that start with 'X' followed by any non whitespace characters and ':'
followed by a space and any number. The number can include a decimal. Then print
the number if it is greater than zero."""
print("Numbers after 'X__:' pattern (alternate approach):")
for line in lines:
    match = re.search(r'X\S+: (\d+(\.\d+)?)', line)
    if match and float(match.group(1)) > 0:
        print(match.group(1))
# Out:
# Numbers after 'X__:' pattern (alternate approach):
# 12.5
# 0.5

# %%
# 9
"""Search for lines that start with 'Details: rev=', followed by numbers and '.'. Then print
the number if it is greater than zero"""
print("Numbers after 'Details: rev=':")
for line in lines:
    match = re.search(r'Details: rev=([\d.]+)', line)
    if match and float(match.group(1)) > 0:
        print(match.group(1))
# Out:
# Numbers after 'Details: rev=':
# 1.2345
# 0.345
# 3.14159
# 2.71828
# 2.0
# 0.123
# 1.618
# 1.732
# 0.5

# %%
# 10
"""Search for lines that start with From and a character followed by a two digit number
between 00 and 99 followed by ':'. Then print the number if it is greater than zero"""
print("Numbers after 'From __ __:' pattern:")
for line in lines:
    match = re.search(r'From [a-zA-Z]([0-9]{2}):', line)
    if match and int(match.group(1)) > 0:
        print(match.group(1))
# Out:
# Numbers after 'From __ __:' pattern:
# 12
# 56
# 45
# 78
# 01
# 99
# 09
# 10
# 17
# 89
# 90
# 34
# 12

# %% [markdown]
# # </h3>Question5. Baby Names Popularity Analysis<h3>
# Reference: https://developers.google.com/edu/python/exercises/baby-names
# The Social Security administration has this neat data by year of what names are most
# popular for babies born that year in the USA. The files baby1990.html baby1992.html ...
# contain raw html pages. Take a look at the html and think about how you might scrape the
# data out of it.
# In the babynames.py file, implement the extract_names(filename) function which takes the
# filename of a baby1990.html file and returns the data from the file as a single list -- the year
# string at the start of the list followed by the name-rank strings in alphabetical order. ['2006',
# 'Aaliyah 91', 'Abagail 895', 'Aaron 57', ...].
#
# Modify main() so it calls your extract_names() function and prints what it returns (main
# already has the code for the command line argument parsing). If you get stuck working out
# the regular expressions for the year and each name, solution regular expression patterns are
# shown at the end of this document. Note that for parsing webpages in general, regular
# expressions don't do a good job, but these webpages have a simple and consistent format.
# Rather than treat the boy and girl names separately, we'll just lump them all together. In
# some years, a name appears more than once in the html, but we'll just use one number per
# name. Optional: make the algorithm smart about this case and choose whichever number is
# smaller.
# Build the program as a series of small milestones, getting each step to run/print something
# before trying the next step. This is the pattern used by experienced programmers -- build a
# series of incremental milestones, each with some output to check, rather than building the
# whole program in one huge step.
#
# Printing the data you have at the end of one milestone helps you think about how to re-
# structure that data for the next milestone. Python is well suited to this style of incremental
#
# development. For example, first get it to the point where it extracts and prints the year and
# calls sys.exit(0). Here are some suggested milestones:
#  Extract all the text from the file and print it
#  Find and extract the year and print it
#  Extract the names and rank numbers and print them
#  Get the names data into a dict and print it
#  Build the [year, 'name rank', ... ] list and print it
#  Fix main() to use the ExtractNames list
# Earlier we have had functions just print to standard out. It's more re-usable to have the
# function *return* the extracted data, so then the caller has the choice to print it or do
# something else with it. (You can still print directly from inside your functions for your little
# experiments during development.)
# Have main() call extract_names() for each command line arg and print a text summary. To
# make the list into a reasonable looking summary text, here's a clever use of join: text =
# '\n'.join(mylist) + '\n'
#
# The summary text should look like this for each file:
# 2006
# Aaliyah 91
# Aaron 57
# Abagail 895
# Abbey 695
# Abbie 650
# ...

# %%
import re

def extract_names(filename):
    # Read the content of the HTML file
    with open(filename, 'r') as file:
        html_content = file.read()

    # Extract the year from the filename
    year_match = re.search(r'baby(\d{4})\.html', filename)
    if year_match:
        year = year_match.group(1)
    else:
        print(f"Could not find the year in the filename: {filename}")
        return None

    # Extract the name-rank strings using regular expressions
    names_rank = re.findall(r'<td>(\d+)</td><td>(\w+)</td><td>(\w+)</td>', html_content)

    # Build the final list with year and name-rank strings
    baby_names_data = [year]
    count = 0
    for rank, boy_name, girl_name in names_rank:
        baby_names_data.append(f"{boy_name} {rank}")
        baby_names_data.append(f"{girl_name} {rank}")
        count+=1
        if count > 10:
            break

    return baby_names_data

def main():
    filenames = "baby1992.html baby1990.html"
    filenames = filenames.split()
    for filename in filenames:
        baby_names_data = extract_names(filename)
        if baby_names_data:
            print('\n'.join(baby_names_data))

        

if __name__ == "__main__":
    main()
# Out:
# 1992
# Michael 1
# Ashley 1
# Christopher 2
# Jessica 2
# Matthew 3
# Amanda 3
# Joshua 4
# Brittany 4
# Andrew 5
# Sarah 5
# Brandon 6
# Samantha 6
# Daniel 7
# Emily 7
# Tyler 8
# Stephanie 8
# James 9
# Elizabeth 9
# David 10
# Megan 10
# Joseph 11
# Jennifer 11
# 1990
# Michael 1
# Jessica 1
# Christopher 2
# Ashley 2
# Matthew 3
# Brittany 3
# Joshua 4
# Amanda 4
# Daniel 5
# Samantha 5
# David 6
# Sarah 6
# Andrew 7
# Stephanie 7
# James 8
# Jennifer 8
# Justin 9
# Elizabeth 9
# Joseph 10
# Lauren 10
# Ryan 11
# Megan 11
